# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Read the CSV into a DataFrame
zev_sales_df = pd.read_csv("ZEV_sales.csv")
zev_sales_df
# Out:
#        Data Year   County FUEL_TYPE       MAKE     MODEL  Number of Vehicles  \
# 0         2015.0  Alameda  Electric        BMW        i3               109.0
# 1         2015.0  Alameda  Electric  Chevrolet  Spark EV               181.0
# 2         2015.0  Alameda  Electric       FIAT      500e               924.0
# 3         2015.0  Alameda  Electric       Ford     Focus                92.0
# 4         2015.0  Alameda  Electric        Kia   Soul EV                59.0
# ...          ...      ...       ...        ...       ...                 ...
# 33695        NaN      NaN       NaN        NaN       NaN                 NaN
# 33696        NaN      NaN       NaN        NaN       NaN                 NaN
# 33697        NaN      NaN       NaN        NaN       NaN                 NaN
# 33698        NaN      NaN       NaN        NaN       NaN                 NaN
# 33699        NaN      NaN       NaN        NaN       NaN                 NaN
#
#          ZIP Fuel Type
# ...

# %%
# Checking for Null values
zev_sales_df.isnull()
# Out:
#        Data Year  County  FUEL_TYPE   MAKE  MODEL  Number of Vehicles    ZIP  \
# 0          False   False      False  False  False               False  False
# 1          False   False      False  False  False               False  False
# 2          False   False      False  False  False               False  False
# 3          False   False      False  False  False               False  False
# 4          False   False      False  False  False               False  False
# ...          ...     ...        ...    ...    ...                 ...    ...
# 33695       True    True       True   True   True                True  False
# 33696       True    True       True   True   True                True  False
# 33697       True    True       True   True   True                True  False
# 33698       True    True       True   True   True                True  False
# 33699       True    True       True   True   True                True  False
#
#        Fuel Type
# 0          False
# ...

# %%
# Dropped ZIP column
zev_sales_df = zev_sales_df.drop('ZIP', axis=1)

# %%
zev_sales_df
# Out:
#        Data Year   County FUEL_TYPE       MAKE     MODEL  Number of Vehicles  \
# 0         2015.0  Alameda  Electric        BMW        i3               109.0
# 1         2015.0  Alameda  Electric  Chevrolet  Spark EV               181.0
# 2         2015.0  Alameda  Electric       FIAT      500e               924.0
# 3         2015.0  Alameda  Electric       Ford     Focus                92.0
# 4         2015.0  Alameda  Electric        Kia   Soul EV                59.0
# ...          ...      ...       ...        ...       ...                 ...
# 33695        NaN      NaN       NaN        NaN       NaN                 NaN
# 33696        NaN      NaN       NaN        NaN       NaN                 NaN
# 33697        NaN      NaN       NaN        NaN       NaN                 NaN
# 33698        NaN      NaN       NaN        NaN       NaN                 NaN
# 33699        NaN      NaN       NaN        NaN       NaN                 NaN
#
#       Fuel Type
# 0      Electric
# ...

# %%
# Dropped Fuel Type column
zev_sales_df = zev_sales_df.drop('Fuel Type', axis=1)

# %%
zev_sales_df
# Out:
#        Data Year   County FUEL_TYPE       MAKE     MODEL  Number of Vehicles
# 0         2015.0  Alameda  Electric        BMW        i3               109.0
# 1         2015.0  Alameda  Electric  Chevrolet  Spark EV               181.0
# 2         2015.0  Alameda  Electric       FIAT      500e               924.0
# 3         2015.0  Alameda  Electric       Ford     Focus                92.0
# 4         2015.0  Alameda  Electric        Kia   Soul EV                59.0
# ...          ...      ...       ...        ...       ...                 ...
# 33695        NaN      NaN       NaN        NaN       NaN                 NaN
# 33696        NaN      NaN       NaN        NaN       NaN                 NaN
# 33697        NaN      NaN       NaN        NaN       NaN                 NaN
# 33698        NaN      NaN       NaN        NaN       NaN                 NaN
# 33699        NaN      NaN       NaN        NaN       NaN                 NaN
#
# [33700 rows x 6 columns]

# %%
# Dropped null values
zev_sales_df = zev_sales_df.dropna()

# %%
zev_sales_df
# Out:
#        Data Year   County FUEL_TYPE       MAKE         MODEL  \
# 0         2015.0  Alameda  Electric        BMW            i3
# 1         2015.0  Alameda  Electric  Chevrolet      Spark EV
# 2         2015.0  Alameda  Electric       FIAT          500e
# 3         2015.0  Alameda  Electric       Ford         Focus
# 4         2015.0  Alameda  Electric        Kia       Soul EV
# ...          ...      ...       ...        ...           ...
# 12770     2022.0     Yuba      PHEV        Kia  Sorento PHEV
# 12771     2022.0     Yuba      PHEV     Toyota   Prius Prime
# 12772     2022.0     Yuba      PHEV     Toyota    RAV4 Prime
# 12773     2022.0     Yuba  Hydrogen    Hyundai          Nexo
# 12774     2022.0     Yuba  Hydrogen     Toyota         Mirai
#
#        Number of Vehicles
# 0                   109.0
# 1                   181.0
# 2                   924.0
# 3                    92.0
# 4                    59.0
# ...                   ...
# 12770                 1.0
# ...
