# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sqlalchemy import create_engine

# %%
#Import demographics dataset
file_path = "C:/Users/VivoBook/Desktop/Classwork/capstoneproject-2022/Data/CA_county_incentives.csv"
incentives_df = pd.read_csv(file_path)
incentives_df.head()
# Out:
#     County Incentive Type     EV Type  Max Amount Requirements Low Income  \
# 0  Alameda         Rebate         BEV      2000.0          Yes         No
# 1  Alameda          Grant         Any      9500.0          Yes        Yes
# 2  Alameda          Grant         Any      5000.0          Yes        Yes
# 3  Alameda  Toll discount         CAV         7.0          Yes         No
# 4  Alameda         Rebate  EV Charger       800.0          Yes         No
#
#   Customer One-time Use                  Program Name or Provider Start Date  \
# 0      Yes          Yes                   Alameda Municipal Power   7/1/2021
# 1      Yes          Yes  Bay Area Air Quality Management District   3/1/2019
# 2       No          Yes          Clean Vehicle Assistance Program   6/1/2018
# 3       No           No            California Air Resources Board   1/1/2019
# 4      Yes          Yes                   Alameda Municipal Power   7/1/2018
#
#    End Date
# 0  1/1/3000
# 1  1/1/3000
# 2  1/1/3000
# 3  1/1/3000
# 4  1/1/3000

# %%
# Drop Provider column
incentives_df = incentives_df.drop(columns="Program Name or Provider", axis=1)  
incentives_df.head()
# Out:
#     County Incentive Type     EV Type  Max Amount Requirements Low Income  \
# 0  Alameda         Rebate         BEV      2000.0          Yes         No
# 1  Alameda          Grant         Any      9500.0          Yes        Yes
# 2  Alameda          Grant         Any      5000.0          Yes        Yes
# 3  Alameda  Toll discount         CAV         7.0          Yes         No
# 4  Alameda         Rebate  EV Charger       800.0          Yes         No
#
#   Customer One-time Use Start Date  End Date
# 0      Yes          Yes   7/1/2021  1/1/3000
# 1      Yes          Yes   3/1/2019  1/1/3000
# 2       No          Yes   6/1/2018  1/1/3000
# 3       No           No   1/1/2019  1/1/3000
# 4      Yes          Yes   7/1/2018  1/1/3000

# %%
# Rename columns to match database table
incentives_df.columns = ["county", "incentive_type", "ev_type",
                   "max_amount", "requirements", "low_income",
                   "customer", "one_time", "start_date", "end_date"]

# %%
# Change requirements columns' values to binary, 0 for no and 1 for yes
incentives_df["requirements"] = incentives_df["requirements"].replace(["Yes", "No"],[1, 0])
incentives_df["low_income"] = incentives_df["low_income"].replace(["Yes", "No"],[1, 0])
incentives_df["customer"] = incentives_df["customer"].replace(["Yes", "No"],[1, 0])
incentives_df["one_time"] = incentives_df["one_time"].replace(["Yes", "No"],[1, 0])
incentives_df.head()
# Out:
#     county incentive_type     ev_type  max_amount  requirements  low_income  \
# 0  Alameda         Rebate         BEV      2000.0             1           0
# 1  Alameda          Grant         Any      9500.0             1           1
# 2  Alameda          Grant         Any      5000.0             1           1
# 3  Alameda  Toll discount         CAV         7.0             1           0
# 4  Alameda         Rebate  EV Charger       800.0             1           0
#
#    customer  one_time start_date  end_date
# 0         1         1   7/1/2021  1/1/3000
# 1         1         1   3/1/2019  1/1/3000
# 2         0         1   6/1/2018  1/1/3000
# 3         0         0   1/1/2019  1/1/3000
# 4         1         1   7/1/2018  1/1/3000

# %%
# Change dtypes
incentives_df = incentives_df.astype({"max_amount": "int"})

incentives_df.dtypes
# Out:
# county            object
# incentive_type    object
# ev_type           object
# max_amount         int32
# requirements       int64
# low_income         int64
# customer           int64
# one_time           int64
# start_date        object
# end_date          object
# dtype: object

# %%
# Save as csv
incentives_df.to_csv("incentives_db.csv", index=False)

# %%
# # Connect data to SQL table, replace to update data
# db_string = f"postgresql://postgres:Ud8zkiE%eS@database-1.cwi16qf0z3wk.ap-southeast-1.rds.amazonaws.com:5432/california_ev_analysis"
# engine = create_engine(db_string)
# incentives_df.to_sql(name="incentives", con=engine, if_exists="replace")

# %%
# Import df to SQL table, replace to update changes
import psycopg2

conn_string = "host='database-1.cwi16qf0z3wk.ap-southeast-1.rds.amazonaws.com' dbname='california_ev_analysis' user='postgres' password='Ud8zkiE%eS'"

conn = psycopg2.connect(conn_string)
incentives_df.to_sql(name="incentives", con=conn, if_exists="replace")
# table = pd.read_sql('SELECT COUNT(*) FROM incentives', conn)
# table
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# SyntaxError: syntax error at or near ";"
# LINE 1: ...ELECT name FROM sqlite_master WHERE type='table' AND name=?;
#                                                                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3956\3287985718.py in <module>
#       5
#       6 conn = psycopg2.connect(conn_string)
# ----> 7 incentives_df.to_sql(name="incentives", con=conn, if_exists="replace")
#       8 # table = pd.read_sql('SELECT COUNT(*) FROM incentives', conn)
#       9 # table
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2223             dtype=dtype,
#    2224         )
# -> 2225         table.create()
#    2226         table.insert(chunksize, method)
#    2227
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in create(self)
#     854
#     855     def create(self):
# --> 856         if self.exists():
#     857             if self.if_exists == "fail":
#     858                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in exists(self)
#     838
#     839     def exists(self):
# --> 840         return self.pd_sql.has_table(self.name, self.schema)
#     841
#     842     def sql_schema(self):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    2234         query = f"SELECT name FROM sqlite_master WHERE type='table' AND name={wld};"
#    2235
# -> 2236         return len(self.execute(query, [name]).fetchall()) > 0
#    2237
#    2238     def get_table(self, table_name: str, schema: str | None = None):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT name FROM sqlite_master WHERE type='table' AND name=?;': syntax error at or near ";"
# LINE 1: ...ELECT name FROM sqlite_master WHERE type='table' AND name=?;
#                                                                       ^
